# %%
#!/usr/bin/python3

""" 
    This is the code to accompany the Lesson 2 (SVM) mini-project.

    Use a SVM to identify emails from the Enron corpus by their authors:    
    Sara has label 0
    Chris has label 1
"""
    
import sys
from time import time
sys.path.append("../SVM/")
from email_preprocess import preprocess


### features_train and features_test are the features for the training
### and testing datasets, respectively
### labels_train and labels_test are the corresponding item labels
features_train, features_test, labels_train, labels_test = preprocess()


#########################################################
### your code goes here ###


from sklearn.svm import SVC
print("Start training")
t0 = time()

#tested with a small sample size
#features_train = features_train[:int(len(features_train)/100)]
#labels_train = labels_train[:int(len(labels_train)/100)]

clf = SVC(kernel='rbf', C = 10000)
clf.fit(features_train, labels_train)
print("training time:", round(time() - t0, 3), "s")

print("Start testing")
t0 = time()
pred = clf.predict(features_test)
print("testing time:", round(time() - t0, 3), "s")


from sklearn.metrics import accuracy_score
acc = accuracy_score(pred, labels_test)
print("Accuracy calculated, and the accuracy is", acc)

#########################################################

print("No. of Chris training emails : ", sum(labels_train))
print("No. of Sara training emails : ", len(labels_train)-sum(labels_train))



#########################################################
'''
You'll be Provided similar code in the Quiz
But the Code provided in Quiz has an Indexing issue
The Code Below solves that issue, So use this one
'''

print ("class for element 10 is ", pred[10])
print ("class for element 26 is ", pred[26])
print ("class for element 50 is ", pred[50])

print('total test ',len(pred))

Chrispred = 0
for item in range(len(pred)):
    if pred[item] == 1:
        Chrispred += 1
print('Chris prediction is', Chrispred)
#########################################################
# Out:
# No. of Chris training emails :  7936
# No. of Sara training emails :  7884
# Start training
# training time: 40.445 s
# Start testing
# testing time: 5.825 s
# Accuracy calculated, and the accuracy is 0.9960182025028441
# No. of Chris training emails :  7936
# No. of Sara training emails :  7884
# class for element 10 is  1
# class for element 26 is  0
# class for element 50 is  1
# total test  1758
# Chris prediction is 866
